# %% [markdown]
# <a href="https://colab.research.google.com/github/Akulamadhumitha/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid describes the hierarchical progression of skills needed for AI development, from foundational to specialized:
#
# *   **Foundational Skills:** Begins with a base of **mathematics, statistics, and core programming skills** (e.g., Python, data structures, algorithms, data manipulation).
# *   **Machine Learning Fundamentals:** Progresses to understanding **core machine learning algorithms, model evaluation, and feature engineering** techniques.
# *   **Advanced AI & Specialization:** Moves into **deep learning architectures and specialized AI domains** like NLP, computer vision, reinforcement learning, or MLOps.
# *   **Domain Expertise & Soft Skills:** Culminates in the **ability to apply AI effectively, ethically, and strategically** within specific business domains, alongside crucial communication and problem-solving skills.
